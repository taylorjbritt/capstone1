# %%
import pandas as pd
import numpy as np
import datetime
from datetime import timedelta
import matplotlib.pyplot as plt


def unpickle(filename):
    df = pd.read_pickle('../data/pickles/' + filename + '.pkl')
    return df

denver = unpickle('denver')

paris = unpickle('paris')

saopaulo = unpickle('saopaulo')

santiago = unpickle('santiago')

nyc = unpickle('nyc')

la = unpickle('la')

madrid = unpickle('madrid')

sydney = unpickle('sydney')

# %%
denver.head(100)
# Out:
#            date  pm10   o3  so2   co  pm25   no2
# 1781 2014-09-01    15  NaN  NaN    2   NaN   6.0
# 1737 2014-09-02    26  NaN  NaN    4  31.0  10.0
# 1738 2014-09-03    27  NaN  NaN    4  35.0  12.0
# 1739 2014-09-04    39  NaN  NaN    3  31.0  11.0
# 1740 2014-09-05   NaN  NaN  NaN    4  40.0   8.0
# ...         ...   ...  ...  ...  ...   ...   ...
# 1712 2014-12-05    38  NaN  NaN    6  73.0  17.0
# 1713 2014-12-06    42  NaN  NaN   10  45.0  16.0
# 1714 2014-12-07    22  NaN  NaN    7  63.0  15.0
# 1715 2014-12-08    59  NaN  NaN   12  36.0  21.0
# 1716 2014-12-09    75  NaN  NaN   15  70.0  23.0
#
# [100 rows x 7 columns]

# %%
def plot_concentrations(df, name):
    fig = plt.figure(figsize=(12,12))
    ax = fig.add_subplot(2,1,1)
    ax.scatter(df['date'], df['pm25'], label = "PM2.5" )
    ax.set_title(name +" "+ 'Air Quality - PM2.5')
    ax.set_ylim(0, (df['pm25'].max()*1.1))
    ax.legend(loc='best')
    fig.tight_layout(pad=1)
    ax = fig.add_subplot(2,1,2)
    ax.scatter(df['date'], df['no2'], label = "NO2" )
    ax.set_title(name +" "+ 'Air Quality - NO2')
    ax.set_ylim(0, (df['no2'].max()*1.1))
    ax.legend(loc='best')
    fig.tight_layout(pad=1)

# %%
plot_concentrations(saopaulo, 'São Paulo')

# %%
plot_concentrations(santiago, 'Santiago de Chile')

# %%
plot_concentrations(denver, 'Denver')

# %%
plot_concentrations(nyc, 'New York City')

# %%
plt.style?

# %%
def plot_concentrations_compare(df1, name1, df2, name2):
    fig = plt.figure(figsize=(12,12))
    ax = fig.add_subplot(2,1,1)
    ax.scatter(df1['date'], df1['pm25'], color = 'blue', alpha = 1, label = name1 )
    ax.scatter(df2['date'], df2['pm25'], color = 'red', alpha = 1, label = name2 )
    ax.set_title(name1 +" "+ 'vs' + " " + name2 + 'Air Quality - PM2.5')
    ax.legend(loc='best')
    fig.tight_layout(pad=1)
    ax = fig.add_subplot(2,1,2)
    ax.scatter(df1['date'], df1['no2'], color = 'blue', alpha = 1, label = name1 )
    ax.scatter(df2['date'], df2['no2'], color = 'red', alpha = 1, label = name2 )
    ax.set_title(name1 +" "+ 'vs' + " " + name2 + 'Air Quality - no2')
    ax.legend(loc='best')
    fig.tight_layout(pad=1)

# %%
plot_concentrations_compare(santiago, 'santiago de chile', denver, 'denver',)

# %%
plot_concentrations_compare(santiago, 'santiago de chile', madrid, 'madrid')

# %%
plot_concentrations_compare(denver, 'denver', sydney, 'sydney')

# %%
denver.head()
# Out:
#            date  pm10   o3  so2  co  pm25   no2
# 1781 2014-09-01    15  NaN  NaN   2   NaN   6.0
# 1737 2014-09-02    26  NaN  NaN   4  31.0  10.0
# 1738 2014-09-03    27  NaN  NaN   4  35.0  12.0
# 1739 2014-09-04    39  NaN  NaN   3  31.0  11.0
# 1740 2014-09-05   NaN  NaN  NaN   4  40.0   8.0

# %%
def days_into_year(df):
    df[days_into_year] =

# %%
denver2 = denver

# %%
denver2[year] = denver['date'].datetime.year()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-f1df4a6572f5> in <module>
# ----> 1 denver2[year] = denver['date'].datetime.year()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'datetime'

# %%
denver2['year'], denver2['month'] = denver2['date'].dt.year, denver2['date'].dt.month

# %%
denver2.head()
# Out:
#            date  pm10   o3  so2  co  pm25   no2  year  month
# 1781 2014-09-01    15  NaN  NaN   2   NaN   6.0  2014      9
# 1737 2014-09-02    26  NaN  NaN   4  31.0  10.0  2014      9
# 1738 2014-09-03    27  NaN  NaN   4  35.0  12.0  2014      9
# 1739 2014-09-04    39  NaN  NaN   3  31.0  11.0  2014      9
# 1740 2014-09-05   NaN  NaN  NaN   4  40.0   8.0  2014      9

# %%
denver2['year'], denver2['month'], denver2['day'] = denver2['date'].dt.year, denver2['date'].dt.month, denver2['date'].dt.day

# %%
denver2.head()
# Out:
#            date  pm10   o3  so2  co  pm25   no2  year  month  day
# 1781 2014-09-01    15  NaN  NaN   2   NaN   6.0  2014      9    1
# 1737 2014-09-02    26  NaN  NaN   4  31.0  10.0  2014      9    2
# 1738 2014-09-03    27  NaN  NaN   4  35.0  12.0  2014      9    3
# 1739 2014-09-04    39  NaN  NaN   3  31.0  11.0  2014      9    4
# 1740 2014-09-05   NaN  NaN  NaN   4  40.0   8.0  2014      9    5

# %%
denver2['days into year'] = datetime.timedelta(denver2['date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-8c78fdde6a90> in <module>
# ----> 1 denver2['days into year'] = datetime.timedelta(denver2['date'])
#
# TypeError: unsupported type for timedelta days component: Series

# %%
denver2['date'].dt.dayofyear()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-63244a69fcb8> in <module>
# ----> 1 denver2['date'].dt.dayofyear()
#
# TypeError: 'Series' object is not callable

# %%
denver2['day_of_year'] = denver['date'].dt.dayofyear

# %%
period = pd.Period("2015-10-23", freq='H')
period.dayofyear

# %%
denver2prev = denver2[denver2['year'] < 2020]

# %%
denver2020 = denver2[denver2['year'] == 2020]

# %%
groupedprev = denver2prev.groupby('day_of_year')

# %%
prev_means = grouped.mean()

# %%
prev_means.head()
# Out:
#                   pm25        no2     year  month  day
# day_of_year
# 1            59.500000  15.333333  2017.00    1.0  1.0
# 2            42.333333  12.000000  2017.75    1.0  2.0
# 3            36.750000  14.000000  2017.40    1.0  3.0
# 4            40.600000  16.600000  2017.40    1.0  4.0
# 5            52.000000  15.800000  2017.40    1.0  5.0

# %%
denver2020.head()
# Out:
#            date  pm10   o3  so2  co  pm25   no2  year  month  day  day_of_year
# 1767 2020-01-01    11  NaN  NaN   4   NaN  12.0  2020      1    1            1
# 65   2020-01-02    16   14  NaN   3  19.0  10.0  2020      1    2            2
# 66   2020-01-03    12   13  NaN   3  16.0  10.0  2020      1    3            3
# 67   2020-01-04    11   14  NaN   3  16.0  11.0  2020      1    4            4
# 68   2020-01-05     8   14  NaN   2  13.0   6.0  2020      1    5            5

# %%
compdf[no22020] = denver2020['no2']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-5703e6635904> in <module>
# ----> 1 compdf[no22020] = denver2020['no2']
#
# NameError: name 'compdf' is not defined

# %%
prev_means['no2_2020'] = denver2020['no2']

# %%
prev_means['pm25_2020'] = denver2020['pm25']

# %%
prev_means.head()
# Out:
#                   pm25        no2     year  month  day  no2_2020  pm25_2020
# day_of_year
# 1            59.500000  15.333333  2017.00    1.0  1.0       6.0       16.0
# 2            42.333333  12.000000  2017.75    1.0  2.0       5.0       35.0
# 3            36.750000  14.000000  2017.40    1.0  3.0       6.0       24.0
# 4            40.600000  16.600000  2017.40    1.0  4.0       NaN       20.0
# 5            52.000000  15.800000  2017.40    1.0  5.0      10.0       20.0

# %%
prev_means['pm25%'] = prev_means['pm25_2020']/prev_means['pm25']

# %%
prev_means['no2%'] = prev_means['no2_2020']/prev_means['no2']

# %%
prev_means.head(20)
# Out:
#                   pm25        no2     year  month   day  no2_2020  pm25_2020  \
# day_of_year
# 1            59.500000  15.333333  2017.00    1.0   1.0       6.0       16.0
# 2            42.333333  12.000000  2017.75    1.0   2.0       5.0       35.0
# 3            36.750000  14.000000  2017.40    1.0   3.0       6.0       24.0
# 4            40.600000  16.600000  2017.40    1.0   4.0       NaN       20.0
# 5            52.000000  15.800000  2017.40    1.0   5.0      10.0       20.0
# 6            44.000000  16.000000  2017.40    1.0   6.0      12.0       61.0
# 7            42.200000  15.166667  2017.50    1.0   7.0      10.0       24.0
# 8            41.400000  16.400000  2017.50    1.0   8.0       7.0       16.0
# 9            46.000000  13.000000  2017.50    1.0   9.0      12.0       16.0
# 10           47.833333  14.000000  2017.50    1.0  10.0      10.0       25.0
# 11           44.666667  14.166667  2017.50    1.0  11.0       6.0       18.0
# ...

# %%
def get_2020_values_as_percent(filename):
    df = unpickle(filename)
    # add column for year and days into a given year
    df['year'] = df['date'].dt.year
    df['day_of_year'] = df['date'].dt.dayofyear
    # split into dataframes for 2020 and for all previous years
    dfprev = df[df['year'] < 2020].sort_values('day_of_year')
    df2020 = df[df['year'] == 2020].sort_values('day_of_year')
    # create a new dataframe with the means of values by day of the previous years
    dfdays = dfprev.groupby('day_of_year').mean()
    dfdays = dfdays.sort_values('day_of_year')
    dfdays['no2_2020'] = df2020['no2']
    dfdays['pm25_2020'] = df2020['pm25']
    dfdays['no2%'] = dfdays['no2_2020']/dfdays['no2']
    dfdays['pm25%'] = dfdays['pm25_2020']/dfdays['pm25']
    dfdays.drop(['year'], axis = 1)
    dfq1 = dfdays[0:91].drop('year', axis=1)
    return dfq1

# %%
get_2020_values_as_percent('madrid')
# Out:
#               co       pm25        no2  no2_2020  pm25_2020      no2%  \
# day_of_year
# 1            NaN  94.000000  35.400000      12.0       35.0  0.338983
# 2            NaN  71.600000  37.200000      10.0       39.0  0.268817
# 3            NaN  61.600000  33.333333       5.0       42.0  0.150000
# 4            NaN  58.500000  33.166667       8.0       45.0  0.241206
# 5            NaN  57.666667  33.666667      12.0       56.0  0.356436
# ...          ...        ...        ...       ...        ...       ...
# 87           NaN  43.333333  26.000000      24.0       32.0  0.923077
# 88           NaN  47.166667  23.000000      25.0       51.0  1.086957
# 89           NaN  43.333333  23.333333      24.0       81.0  1.028571
# 90           NaN  43.166667  27.500000      21.0       65.0  0.763636
# 91           NaN  47.833333  22.833333      21.0       68.0  0.919708
#
#                 pm25%
# day_of_year
# 1            0.372340
# 2            0.544693
# 3            0.681818
# ...

# %%
def plot_2020_as_percent(filename, substance = 'no2'):
    df = get_2020_values_as_percent(filename)
    fig, ax = plt.subplots(figsize=(16,8))
    x = np.arange(0, len(df))
    y = (df[substance+'%'])*100
    ax.plot(x, y, linewidth = 3)
    ax.set_xlabel('Days Since January 1st')
    ax.set_ylabel('2020 '+substance+' AQI as a percentage of previous years')
    ax.axhline(100, ls='--')

# %%
plot_2020_as_percent('madrid', 'no2')

# %%
plot_2020_as_percent('denver')

# %%
dftest = get_2020_values_as_percent('paris')

# %%
dftest
# Out:
#                   pm25        no2         year          day  no2_2020  \
# day_of_year
# 1            74.500000  32.500000  2017.166667  2017.166667      26.0
# 2            74.166667  38.142857  2017.000000  2017.000000      22.0
# 3            64.000000  35.428571  2017.000000  2017.000000      16.0
# 4            55.428571  39.285714  2017.000000  2017.000000      27.0
# 5            57.714286  40.571429  2017.000000  2017.000000      20.0
# ...                ...        ...          ...          ...       ...
# 86           76.714286  47.714286  2017.000000  2017.000000      34.0
# 87           78.571429  41.571429  2017.000000  2017.000000      33.0
# 88           75.857143  40.142857  2017.000000  2017.000000      32.0
# 89           70.285714  46.714286  2017.000000  2017.000000      33.0
# 90           60.000000  45.285714  2017.000000  2017.000000      39.0
#
#              pm25_2020      no2%     pm25%
# day_of_year
# 1                 61.0  0.800000  0.818792
# ...

# %%
plot_2020_as_percent('paris')
